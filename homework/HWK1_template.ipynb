# %% [markdown]
# # Step 1: Introduction in text

# %% [markdown]
# **Add a Markdown text block** to provide responses for the following questions via complete sentences (150 - 250 words)
# *  What is your major?
# *  What is your class standing (freshman, sophomore, junior, or senior)
# *  What is your career aspiration?
# *  How do you see CS 201 relate to your career aspiration?
# *  List a couple personal interests of data, e.g. music, sports, food, exercises, health, etc.
# *  List a couple professional interests of data, e.g. education, health, crime, poverty, wealth, etc.

# %% [markdown]
# # Step 2 Introduction via assignments

# %%
# Here is an example to help you see how to assign a data to a variable
years = 28

# %% [markdown]
# **Add a code block** to include at least six assignments that assign data about you to descriptive variable names. As a reminder, please use descriptive variable names to help explain the purpose of these data.
# *  Two of them should be whole numbers: For example, these could be the number of hours your work in a week, number of units you have completed or are currently taking, etc.
# *  Two of them should be numbers with decimal values: For example, these could be the distance your have to travel for school or work, the price of an item you purchased or wish to purchase, etc.
# *  Two of them should be text values: For example, these could be your favoriate dish, your dream vacation destination, your hometown, etc.

# %% [markdown]
# # Step 3 Intrdocution via the print function

# %%
# Here are two ways of using the print function to include
# the value of a variable in a sentence context
# It works when the code block assigning 28 to years is run

print('I have been working at CSUSM for', years, 'years.')
print(f'I have been working at CSUSM for {years} years.')
# Out:
# I have been working at CSUSM for 28 years.
# I have been working at CSUSM for 28 years.

# %% [markdown]
# **Add a code block** to use the print function to display the values of the variables you assigned in step 2 in sentences.

# %% [markdown]
# # Step 4 Reflection

# %% [markdown]
# **Add a Markdown text block** to reflect upon your experience with this assignment and respond to the following questions using complete sentences (~100 words)
# *  How do you feel about the level of difficulty in coming up with interesting data about yourself?
# *  In your own words, describe what an assignment statement does. What tips do you have for creating good assignment statements?
# *  In your own words, explain how to use the print function to display the value of a variable along with other text.
