# %% [markdown]
# # Data preparation

# %% [markdown]
# The following code block prepares a DataFrame object that holds the percentage of populations by age groups extracted from the [HDPulse Data Portal](https://hdpulse.nimhd.nih.gov/data-portal/home).
#
# For example,
#
# *  for Alabama, 22.3% of its population was under 18, 28.5% was between age 18 - 39, 31.7% between age 40 - 64, and 17.5% was 65 or older.
# *  for Wyoming, 22.8% of its population was under 18, 28.6% was between age 18 - 39, 30.5% between age 40 - 64, and 18.0% was 65 or older.

# %%
# Make sure to run this code block before the rest of the code blocks.
import pandas as pd
data = {'State': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
       'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
       'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
       'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
       'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
       'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
       'New Jersey', 'New Mexico', 'New York', 'North Carolina',
       'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
       'Puerto Rico', 'Rhode Island', 'South Carolina', 'South Dakota',
       'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
       'West Virginia', 'Wisconsin', 'Wyoming'],
        'Under 18':[22.3, 24.3, 21.9, 23.3, 22.2, 21.4, 20.4, 20.9, 18.7, 19.6,
                    23.5, 20.9, 24.5, 22.1, 23.4, 23.0, 24.0, 22.7, 23.6, 18.3,
                    22.3, 19.6, 21.4, 23.1, 23.5, 22.5, 21.3, 24.7, 22.1, 18.5,
                    21.9, 22.1, 20.7, 21.9, 23.7, 22.2, 24.1, 20.2, 20.6, 16.7,
                    19.0, 21.6, 24.4, 22.3, 25.2, 28.3, 18.2, 21.9, 21.6, 20.1, 21.6, 22.8],
        'Age 18 - 39':[28.5, 32.2, 29.5, 28.7, 31.1, 32.3, 28.1, 27.2, 40.8, 27.1,
                       30.0, 28.4, 29.3, 29.4, 29.1, 28.8, 29.7, 28.5, 29.5, 26.1,
                       28.7, 30.4, 28.5, 28.8, 28.6, 28.9, 28.4, 29.3, 29.5, 27.7,
                       27.9, 29.0, 29.8, 29.2, 32.2, 28.3, 30.0, 29.6, 28.3, 27.9,
                       30.4, 28.3, 28.6, 29.2, 31.2, 33.3, 28.2, 29.7, 31.0, 26.4, 28.3, 28.6],
        'Age 40 - 64':[31.7, 30.2, 30.0, 30.7, 31.4, 31.2, 33.4, 31.8, 27.8, 32.2,
                       31.9, 30.8, 29.7, 32.0, 31.1, 30.4, 29.7, 31.8, 30.7, 33.7,
                       32.8, 32.5, 31.9, 31.3, 31.2, 31.1, 30.6, 29.6, 31.8, 34.3,
                       33.4, 30.2, 32.1, 32.0, 27.9, 31.7, 29.8, 31.6, 32.0, 32.6,
                       32.4, 31.6, 29.3, 31.8, 30.3, 26.8, 32.8, 32.1, 31.1, 32.8, 32.1, 30.5],
        '65 and Over':[17.5, 13.3, 18.6, 17.3, 15.3, 15.2, 18.1, 20.0, 12.7, 21.1,
                       14.6, 19.9, 16.6, 16.6, 16.4, 17.8, 16.6, 17.0, 16.3, 21.9,
                       16.3, 17.5, 18.2, 16.8, 16.8, 17.5, 19.7, 16.4, 16.6, 19.5,
                       16.8, 18.8, 17.4, 16.9, 16.2, 17.9, 16.1, 18.6, 19.1, 22.7,
                       18.3, 18.5, 17.6, 16.8, 13.2, 11.6, 20.8, 16.3, 16.3, 20.7, 18.0, 18.0]}
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        52 non-null     object
#  1   Under 18     52 non-null     float64
#  2   Age 18 - 39  52 non-null     float64
#  3   Age 40 - 64  52 non-null     float64
#  4   65 and Over  52 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# # Step 1 Filtering

# %%
# Create, save, and show a DataFrame that holds rows of states whose 65 and Over
# population are higher than 18.8%

# %%
# Create, save, and show a DataFrame that holds rows of states whose Age 18 - 39
# population are under 28%

# %%
# Create, save, and show a DataFrame that holds rows for California and five other
# states of your choice

# %% [markdown]
# **Add a text block** to answer the following questions:
#
# *  What are the percentages for different age groups in California?
# *  How many states have their 65 and over population higher than 18.8%?
# *  How many states have their 18 - 39 population under 28%?
# *  What do you think about the age distributions for the selected states?

# %% [markdown]
# # Step 2 Ranking

# %% [markdown]
# Choose one of the DataFrame object you created in Step 1 to complete the exercises in this step.

# %%
# Add ranking for the rows based on their values in the 'Under 18' column.
# Set the highest value as rank 1. Use 'dense' to break ties.

# %%
# Add ranking for the rows based on their values in the 'Age 40 - 64' column.
# Set the lowest value as rank 1. Use 'min' to break ties.

# %% [markdown]
# # Step 3 Sorting

# %% [markdown]
# Choose a different DataFrame object you created in Step 1 to complete the exercises in this step.

# %%
# Sort the dataset by the values in the 'Under 18' column in ascending order.
# Show the sorted dataset

# %%
# Sort the dataset by the values in the 'Age 40 - 64' column in descending order.
# Show the sorted dataset

# %% [markdown]
# # Step 4 Counting

# %% [markdown]
# Apply the conditions in this step to the original DataFrame object.

# %%
# Count and show the number of states whose under 18 populations are between 21.6 and 23.5

# %%
# Count and show the number of states whose 18 - 39 populations are outside of the ranges
# of 28.2 and 30.

# %% [markdown]
# # Step 5 Reflection

# %% [markdown]
# **Add a text block** to reflect upon your experience with this assignment and respond to the following questions using complete sentences (~100 words)
#
# *  In your own words, explain the importance/benefits of applying filters on a large dataset.
# *  In your own words, discuss how ranking and sorting help us understand data.
# *  What did you learn about the age distributions through this assignment?
# *  List two additional questions you have about the age distributions among different states?
