# %% [markdown]
# # Data Source

# %% [markdown]
# The [HDPulse Data Portal](https://hdpulse.nimhd.nih.gov/data-portal/home) hosts statistics, charts, and maps by data topic across the health disparities continuum.For example, under Social, Economic, & Cultural Environment, we can find [incarcenation data by states on](https://hdpulse.nimhd.nih.gov/data-portal/social/map?age=001&age_options=age25_1&demo=231&demo_options=education_3&race=00&race_options=race_7&sex=0&sex_options=sexboth_1&socialtopic=025&socialtopic_options=social_6&statefips=00&statefips_options=area_states) the number of children ever having a parent or guardian serve time in jailall.

# %% [markdown]
# # Step 1 List indexing

# %% [markdown]
# Run the following code block first before completing the exercises in this step.

# %%
# This is a list of 10 states
states = ['Arizona', 'California', 'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico', 'Utah', 'Washington', 'Wyoming']

# This list holds the percentages of children ever having a parent or guardian serve time in jail for
# the 10 states in the above list
rates = [6.6, 4.2, 6.4, 7.7, 8.6, 4.5, 7.4, 4.1, 6.1, 10.3]

# This list holds the levels of parent/gaurdian incarceration for the 10 states above
levels = ['medium high', 'medium low', 'medium high', 'high', 'high', 'medium low', 'high', 'low', 'medium high', 'very high']

# %% [markdown]
# Complete the following code blocks according to the comments.

# %%
# Use an appropriate index along with the states list to display 'Arizona'

# %%
# Use an appropriate index along with the rates list to display the incarceration rate for California

# %%
# Use an appropriate index along with the rates list to display the incarceration rate for New Mexico

# %%
# Use an appropriate index along with the levels list to display the incarceration level for Montana

# %%
# Use an appropriate index along with the levels list to display the incarceration level for Wyoming

# %% [markdown]
# # Step 2 List slicing

# %% [markdown]
# Run the following code block first before completing the exercises in this step.

# %%
# This is a list of 10 states
states = ['Arizona', 'California', 'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico', 'Utah', 'Washington', 'Wyoming']

# %% [markdown]
# Complete the following code blocks according to the comments.

# %%
# Extract 'Arizona', 'California', 'Colorado', 'Idaho'

# %%
# Extract 'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico'

# %%
# Extract 'Montana', 'Nevada', 'New Mexico', 'Utah', 'Washington', 'Wyoming'

# %%
# Extract 'California', 'Montana', 'Utah'

# %%
# Extract 'Arizona', 'Colorado', 'Montana', 'New Mexico', 'Washington'

# %% [markdown]
# # Step 3 List comprehension

# %% [markdown]
# Run the following code block first before completing the exercises in this step.

# %%
# This list holds the percentages of children ever having a parent or guardian serve time in jail for
# the 50 states in alphabetical order of the state names
rates = [8.1, 6.6, 6.6, 12.6, 4.2, 6.4, 3.5, 6.6, 5.1, 8.1,
         4.1, 7.7, 4.6, 7.9, 8.1, 5.7, 11.6, 9.4, 8.1, 3.1,
         1.9, 7.1, 3.9, 8.3, 8.7, 8.6, 6.0, 4.5, 5.4, 3.8,
         7.4, 1.6, 7.7, 9.7, 6.6, 10.8, 5.0, 6.2, 2.7, 4.5,
         10.4, 9.9, 5.5, 4.1, 4.2, 6.0, 6.1, 10.9, 4.6, 10.3]

# This list holds the levels of parent/gaurdian incarceration for the 50 states in alphabetical order of the state names
levels = ['high', 'medium high', 'medium high', 'very high', 'medium low',
          'medium high', 'low', 'medium high', 'medium low', 'high',
          'low', 'high', 'medium low', 'high', 'high',
          'medium high', 'very high', 'very high', 'high', 'low',
          'low', 'medium high', 'low', 'high', 'very high',
          'high', 'medium high', 'medium low', 'medium low', 'low',
          'high', 'low', 'high', 'very high', 'medium high',
          'very high', 'medium low', 'medium high', 'low', 'medium low',
          'very high', 'very high', 'medium low', 'low', 'medium low',
          'medium high', 'medium high', 'very high', 'medium low', 'very high']

# %% [markdown]
# Complete the following code blocks according to the comments.

# %%
# Create and show a sublist of rates under 7.1 (i.e. does not include 7.1)

# %%
# Create and show a sublist of rates 8.6 and above (remember to include 8.6)

# %%
# Create and show a sublist of rates between 5.6 and 8.6, inclusively

# %%
# Create and show a sublist of rates outside the range of 5.6 and 8.6

# %%
# create and show a sublist of incarceration levels that are 'high'

# %%
# Create and show a sublist of incarceration levels that are 'medium low' or 'medium high'

# %%
# Create and show a sublist of incarceration levels that are neither 'low' nor 'very high'

# %% [markdown]
# # Step 4 Reflection

# %% [markdown]
# **Add a text block** to reflect upon your experience with this assignment and respond to the following questions using complete sentences (~100 words)
# *  In your own words, describe how Python using indexing to help locate an element of a list.
# *  What strategies would you recommend when finding the start, stop, and step values of list slicing?
# *  How do you feel about the level of difficulty for Step 3 List comprehension? What tips do you have for using the logical operators?
# *  Explore the [HDPulse Data Portal](https://hdpulse.nimhd.nih.gov/data-portal/home). Did you find any interesting data?
