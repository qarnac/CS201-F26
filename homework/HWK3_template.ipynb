# %% [markdown]
# # Step 1: Descriptive statistics

# %% [markdown]
# The following data are taken from the [HDPulse Data Portal](https://hdpulse.nimhd.nih.gov/data-portal/home). It's important to run this code block before completing the exercises in this step of the assignment.

# %%
# This list holds the percentages of children ever having a parent or guardian serve time in jail for
# the 50 states in alphabetical order of the state names
incarceration = [8.1, 6.6, 6.6, 12.6, 4.2, 6.4, 3.5, 6.6, 5.1, 8.1,
         4.1, 7.7, 4.6, 7.9, 8.1, 5.7, 11.6, 9.4, 8.1, 3.1,
         1.9, 7.1, 3.9, 8.3, 8.7, 8.6, 6.0, 4.5, 5.4, 3.8,
         7.4, 1.6, 7.7, 9.7, 6.6, 10.8, 5.0, 6.2, 2.7, 4.5,
         10.4, 9.9, 5.5, 4.1, 4.2, 6.0, 6.1, 10.9, 4.6, 10.3]

# This list holds the percentages of families below poverty for the 50 states
# in alphabetical order of the state names
poverty = [11.3, 6.8, 8.9, 11.5, 8.4, 5.9, 6.8, 7.3, 8.9, 9.9,
          6.9, 7.0, 8.2, 8.4, 6.9, 7.7, 11.8, 14.2, 6.5, 6.3,
          6.6, 8.8, 5.5, 14.3, 8.4, 7.1, 6.7, 9.0, 4.4, 7.0,
          13.7, 9.8, 9.4, 6.2, 9.2, 11.1, 7.3, 8.1, 7.0, 10.1,
          7.4, 9.9, 10.5, 5.7, 5.7, 6.8, 6.4, 11.9, 6.6, 7.1]

# %% [markdown]
# Complete the following code blocks according to the comments.

# %%
# Use the min and max functions to help determine and show the lowest and highest incarceration rates

# %%
# Use the min and max functions to help determine and show the range of poverty levels

# %%
# Create a sublist of incarceration values under 7.1. Use the len function to help
# find out the number of items in the sublist.

# %%
# Create a sublist of poverty values between 5.5 and 8.6. Use the len function to help
# find out the number of items in the sublist.

# %%
# Use the related functions from the statistics library to help determine and show
# the average, median, and stanadard deviation of incarceration rates among the 50 states

# %%
# Use the related functions from the statistics library to help determine and show
# the average, median, and stanadard deviation of poverty levels among the 50 states

# %% [markdown]
# # Step 2 DataFrame

# %% [markdown]
# Explore the [HDPulse Data Portal](https://hdpulse.nimhd.nih.gov/data-portal/home) to pick two fields that are not incarceration nor poverty.

# %%
# Create a DataFrame object to include data for at least 10 states.

# %%
# Call the head function to show the first three rows of the DataFrame object

# %%
# Call the tail function to show the last three rows of the DataFrame object

# %%
# Use the shape attribute to show the number of rows and columns of the DataFrame object.

# %%
# Use the columns attribute to show the names of the columns of the DataFrame object

# %%
# Call the info function to show more details about the DataFrame object

# %%
# Call the describe function to show descriptive statistics for the DataFrame object

# %% [markdown]
# **Add a Markdown text block** to explain the results of the describe function. What are the values for the following descriptive statistics for the two fields? Smallest, largest, median, average, and standard deviation

# %% [markdown]
# # Step 3 Reflection

# %% [markdown]
# **Add a Markdown text block** to reflect upon your experience with this assignment and respond to the following questions using complete sentences (~100 words)
#
# *  In your own words, explain the importance/benefits of using average and standard deviation to communicate about a large dataset.
# *  Assume that a DataFrame object is created to hold data of 50 states about the two fields of your choice. What are some questions you are interested in learning about the two fields from the dataset?
