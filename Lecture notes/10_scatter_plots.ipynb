# %% [markdown]
# # Data Preparation

# %% [markdown]
# The rest of this page depends on the successful loading of the CSV data into df. Therefore, whenever you open or reconnect to this page, it is important to always **run this code block first** before working on the other code blocks of the page.

# %%
import pandas as pd
# set float display format to comma as thousand separator and 2 digits after the decimal point
pd.options.display.float_format = '{:,.2f}'.format

df = pd.read_csv('https://raw.githubusercontent.com/qarnac/cs201/refs/heads/main/insured_by_states_18_64.csv')
df.columns

# I created this dataset using HDPulse data under Healthcare System -> Insurance
# The data shows how many people aged 18 - 64 were insured in 2023
# It is critical to run this block first before running any of the following code blocks. Otherwise, data will not be ready in df.
# Out:
# Index(['State', 'All_Percent', 'All_People', 'White_Percent', 'White_People',
#        'Black_Percent', 'Black_People', 'AI_AN_Percent', 'AI_AN_People',
#        'API_Percent', 'API_People', 'Hispanic_Percent', 'Hispanic_People'],
#       dtype='object')

# %% [markdown]
# ## Data wrangling practice

# %% [markdown]
# Complete the following data wrangling tasks. You may use as many or as few code blocks.
#
# *  Create a new DataFrame object called **percent_df** to hold a copy of only the percentage coverage for different states.
# *  Rename the columns in **percent_df** to remove the postfix `_Percent`.
# *  Create a new column in **percent_df** to hold the difference of percentage coverage for two races of your choice.
# *  Create a new column in **percent_df** to rank the states according to one numeric column of your choice.
# *  Create a new column in **percent_df** to label the states as top, middle, and bottom based on the rank you created.

# %% [markdown]
# # Scatter plots

# %% [markdown]
# Scatter plots are a powerful way to explore relationships between two numerical variables, making them especially useful for our dataset. For example, we can examine whether states with higher overall insurance coverage also tend to have higher coverage for specific racial groups, or whether populations of different sizes show more variability in coverage rates. By displaying each state as a dot/circle, scatter plots help reveal patterns, clusters, and outliers that might be hard to see in tables alone, offering an intuitive starting point for deeper analysis.
#
# The `plot` function we used for bar charts and histograms can also be used to create a histogram as shown in the following code block.
#
# *  We need to set the `kind` parameter to `'scatter'` instead of `'bar'` or `'hist'`.
# *  The `x` parameter specifies the column whose values will be used for the x-axis.
# *  The `y` parameter specifies the column whose values will be used for the y-axis.
# *  The `figsize` parameter specifies the width and height of the figure.
# *  The `alpha` parameter specifies the level of transparency for each dot, 0 for fully transparent and 1 for fully opaque. The default value is 1.
# *  The `s` parameter specifies the size of the dots, 20 for a small dot, 50 - 80 for a medium dot, and 150 - 300 for a large dot.
# *  The `grid` parameter specifies whether to show a grid in the background. The default value is `False`.

# %%
import matplotlib.pyplot as plt     # import appropriate library

# create a scatter plot
df.plot(kind='scatter',             #Indicate the kind of plot to be generated
        x='All_Percent',            #Identify the column for the x_axis
        y='All_People',             #Identify the column for the y-axis
        figsize=(6, 4),             #Set up the width and height of the graph
        title='People versus Percent (All Races)',  #Set up the title of the graph
        s=80,                       #Indicate the size of each dot
        alpha=0.5,                  #Indicate the level of transparency
        color='red',                #Indicate the color for the dots
        grid=True                   #Decide whether to use grid
)

plt.tight_layout()                  # adjust spacing to avoid overlap
plt.show()                          # show the chart

# %% [markdown]
# The above scatter plot shows the following
# *  Each dot in the graph represent one state. Some dots are overlapping with each other, indicating those states have similar percentage and people coverages.
# *  The x-axis are marked by ranges of the percentage values.
# *  The y-axis are marked by ranges of the people insured. The 1e7 on the top indicates a unit of 10 million.
# *  The left most dot in the graph is for a state with the lowest percentage coverage (around 78%). Its corresponding y value indicates that close to 15 million people were insured in that state.
# *  The highest dot in the graph is for a state with the highest number of people insured (over 20 million). Its corresponding x value indicates that percentage coverage for that state is around 91%.
# *  There is no pattern showing that higher percentage coverages correspond to higher number of people covered for the states.
#
# Let's take a look at another scatter plot generated by the following code block.

# %%
import matplotlib.pyplot as plt     # import appropriate library

# create a scatter plot
df.plot(kind='scatter',             #Indicate the kind of plot to be generated
        x='All_Percent',            #Identify the column for the x_axis
        y='White_Percent',             #Identify the column for the y-axis
        figsize=(6, 4),             #Set up the width and height of the graph
        title='Percentage Coverage (White vs Overall)',  #Set up the title of the graph
        s=80,                       #Indicate the size of each dot
        alpha=0.5,                  #Indicate the level of transparency
        color='steelblue',          #Indicate the color for the dots
        grid=True                   #Decide whether to use grid
)

plt.tight_layout()                  # adjust spacing to avoid overlap
plt.show()                          # show the chart

# %% [markdown]
# There are a few things we can observe from the above scatter plot
#
# *  Both the x-axis and y-axis are marked with percentage coverage.
# *  The lowest dot is for a state that has the lowest white coverage (around 86%). It has a relatively low overall coverrage (around 84%).
# *  The left most dot is for a state that has the lowest overall coverage (around 78%). It has a relatively low white coverage (around 87.5%).
# *  There is a clear trend of higher overall coverage percentage and white coverage percentages.
# The following code block shows the distribution of coverage for states whose number of people insured are between 1 and 10 million.

# %% [markdown]
# ## Practice

# %% [markdown]
# Complete the following two scatter plot using `percent_df`.

# %%
# Create a scatter plot between the coverages for two races of your choice

# %%
# Create a scatter plot between the overall coverage and the column you created for the difference between two races.

# %%
# optional: create a scatter plot of your choice

# %% [markdown]
# **Add a text block** to explain what you learn from the above scatter plots.

# %% [markdown]
# The plot function can also encode a third column as color in a scatter plot. This is done through the c and cmap parameters.
#
# * The c parameter supplies values used to decide how to color each dot.
# * The cmap identifies the color maps to be used. Here are some common ones
#     *  'viridis': dark purple -> blue -> green -> yellow
#     *  'plasma': dark purple -> red -> orange -> yellow
#     *  'coolwarm': blue -> white -> red
#     *  'seismic': deep blue -> white -> deep red
#     *  'tab10': 10 distinct, bright colors
#     *  'Set1': softer pastels or bold hues

# %%
import matplotlib.pyplot as plt     # import appropriate library

# create a scatter plot
df.plot(kind='scatter',             #Indicate the kind of plot to be generated
        x='All_Percent',            #Identify the column for the x_axis
        y='All_People',             #Identify the column for the y-axis
        c='White_Percent',          #Identify the column whose values will be used to determine colors
        cmap='coolwarm',            # blue->white->red
        figsize=(6, 4),             #Set up the width and height of the graph
        title='Insurance Coverage (People vs Percentage)',  #Set up the title of the graph
        s=80,                       #Indicate the size of each dot
        alpha=0.9,                  #Indicate the level of transparency
        grid=True                   #Decide whether to use grid
)

plt.tight_layout()                  # adjust spacing to avoid overlap
plt.show()                          # show the chart

# %% [markdown]
# There are a few things we can observe from the colors in the above scatter plot
#
# *  The color bar shows that states with lower White_Percent receive blue colors while the states with higher White_Percent receive red colors.
#     *  The darker the blue a dot is, the lower White_Percent for the state.
#     *  The darker the red a dot is, the higher White_Percent for the state.
#
# *  The scatter plot shows most blue dots are to the left of the red dots. That is, states with lower White_Percent also have lower All_Percent. This is consistent as what we saw in the scatter plot betweel All_Percent and White_Percent.
# *  There is not clear distinction of colors between the dots of higher and lower values of All_People. Therefore, we don't see a direct impact of White_Percent on the total number of people covered by their states.
#
# The above code block uses a numeric column, 'White_Percent', to determine the colors of the dots. We can also use a categorical column to set colors of the dots.

# %%
import matplotlib.pyplot as plt     # import appropriate library

# data wranglin
df['Population'] = df['All_People'] * 100 / df['All_Percent']
population_bins = [0, 1000000, 5000000, 10000000, 30000000]
size_labels=['Small', 'Medium', 'Large', 'Very Large']
df['State_Size'] = pd.cut(df['Population'], bins=population_bins, labels=size_labels)

# create a scatter plot
df.plot(kind='scatter',             #Indicate the kind of plot to be generated
        x='All_Percent',            #Identify the column for the x_axis
        y='All_People',             #Identify the column for the y-axis
        c='State_Size',          #Identify the column whose values will be used to determine colors
        cmap='tab10',            # blue->white->red
        figsize=(6, 4),             #Set up the width and height of the graph
        title='Insurance Coverage (People vs Percentage)',  #Set up the title of the graph
        s=80,                       #Indicate the size of each dot
        alpha=0.5,                  #Indicate the level of transparency
        grid=True                   #Decide whether to use grid
)

plt.tight_layout()                  # adjust spacing to avoid overlap
plt.show()                          # show the chart

# %% [markdown]
# There are a few things we can observe from the colors in the above scatter plot
#
# *  The color bar shows that states of different sizes receive different colors.
#     *  Blue is for small states, i.e. with population under 1 million.
#     *  Red is for medium states, i.e. with population between 1 and 5 million
#     *  Pink is for large states, i.e. with population between 5 and 10 million.
#     *  Green is for very large states, i.e. with population above 10 million.
#
# *  All blue dots are lower than the red dots, indicating small states have less coverage in terms of the number of people than medium states.
# *  All green dots are higher than dots of other colors, indicating very large states have more coverage in terms of the number of people than other states.
# *  There is not clear distinction of colors between the dots of higher and lower values of All_Percent. Therefore, we don't see a direct impact of state size on the percentage coverage by their states.

# %% [markdown]
# ## Practice

# %% [markdown]
# Complete the following two scatter plot using `percent_df`.

# %%
# Create a scatter plot between the coverages for two races of your choice
# using another numeric column for the colors of the dots

# %%
# Create a scatter plot between the overall coverage and the column you created for the difference between two races
# using the column of top, middle, and bottom for the colors of the dots.

# %%
# optional: create a scatter plot of your choice

# %% [markdown]
# **Add a text block** to explain what you learn from the above scatter plots.

# %% [markdown]
# # Compare the three visualizations

# %% [markdown]
# **Add a text block** to discuss how you feel about the three visualizations we learn: bar chart, histogram, scatter plot
#
# *  How do you feel about using the `plot` function to create these visualizations? Is there one that you feel more comfortable than the others? Is there one that you struggle more than the others?
# *  List some questions about the dataset for which bar charts can provide insights.
# *  List some questions about the dataset for which histograms can provide insights.
# *  List some questions about the dataset for which scatter plots can provide insights.
