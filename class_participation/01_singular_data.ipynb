# %% [markdown]
# # Data

# %% [markdown]
# **Data** are descriptions/measurements of the world around us. They may be **quantitative**, e.g. one's age, height, wage, or **qualitative**, one's name, ethnicity, political views. The following code blocks show examples of representing data in Python.
#
# Quantitative data could be integers (whole numbers) or floating point numbers (has decimal values). Examples are shown in the following code blocks.

# %%
123
# Out:
# 123

# %%
3.14159
# Out:
# 3.14159

# %% [markdown]
# Qualitative data are described in Python using quotes to enclose them as shown in the following code blocks.

# %%
"Data Science"
# Out:
# 'Data Science'

# %%
'San Marcos'
# Out:
# 'San Marcos'

# %% [markdown]
# ## Practice

# %% [markdown]
# Complete the following code block according to the comments provided. `#` is used to indicate the start of a **comment** in a line. A comment is a note for the developer.

# %%
# Write an integer value (whole number)

# %%
# Write a floating point number (with decimal value)

# %%
# Write a text value using quotes

# %% [markdown]
# Add a Markdown text block below and write a fun fact about yourself.

# %% [markdown]
# # Variables

# %% [markdown]
# The term **variable** refers to the name we use to identify a piece of data our program will be working with. Each name may contain letters, underscores, or digits but cannot start with a digit. It is important to give each variable a descriptive name to make it easy for us to remember what the data is about. Here are example valid variable names. When more than one words are used for a variable name, it is common to use an underscore to connect them. Do not use space or other special characters in a variable name.
# *  name
# *  age
# *  salary
# *  first_name
# *  last_name
# *  age_limit
# *  annual_salary
#
# There are some words that Python has already used them for specific purpose. They are referred to as **reserved words** or **keywords**. Do not use them as your variable names.
#
# ![python keyword](https://www.devopsschool.com/blog/wp-content/uploads/2020/08/keyword-in-python.png)

# %% [markdown]
# # Assign and retrieve data

# %% [markdown]
# An **assignment statement** allows you to assign a value to a variable using the `=` operator.
#
# *   Each assignment statement assigns a value on the right of `=` to a variable on the left of `=`.
# *   Google Colab uses different colors to make it easier for us to read Python code.
#
# The following code block contains some example Assignment Statements.
# *   When enclosing text values in quotes, you may use either single quotes, e.g. `'Science II'`, or double quotes, e.g. `"Youwen Ouyang"` for each value. But don't mix match the quotes. For example, `'California"` or `"United States'` would cause errors.
# *   Don't include any measurement unit as part of a numeric value. For example, we only assign 28.7 not 28.7 years for years_at_CSUSM.
# *   Don't use commas to separate thousands in a numeric value. For example, we don't want to use 31,820 for steps_per_week.

# %%
name = "Youwen Ouyang"
office_building = 'Science II'
office_room_number = 219
years_at_CSUSM = 28.7
steps_per_week = 31820

# %% [markdown]
# Running the above code block will assign different values to respective variables. It does not show any output. A quick way to find out what value has been saved in a variable, you can simply list the variable name as illustrated below.

# %%
# Make sure that you run the code block of the assignments first
office_building
# Out:
# 'Science II'

# %% [markdown]
# We can also combine the assigning and retrieving of data in the same code block as shown below.

# %%
county = 'San Diego'  #Assigning a value to a variable stores the value in the corresponding memory space
county                #retrieving the value stored in a variable is done by using its name
# Out:
# 'San Diego'

# %% [markdown]
# To show data from multiple variables, simply list them one after another using commas as separators.

# %%
county = 'San Diego'
city = "San Marcos"
populations = 70301
county, city, populations   #Retrieving data from multiple variables
# Out:
# ('San Diego', 'San Marcos', 70301)

# %% [markdown]
# Note that only values for variables listed at the end of each code block will be shown.

# %%
county = 'San Diego'
city = "San Marcos"
populations = 70301
county, city, populations #The output will not show these values since they are not at the end of the block.
gas_rating = 87
current_average = 5.013
yesterday_average = 5.025
gas_rating, current_average, yesterday_average
# Out:
# (87, 5.013, 5.025)

# %%
city, populations
# Out:
# ('San Marcos', 70301)

# %% [markdown]
# ***Important***
#
# Google gives us a virtual machine when we visit a Google Colab notebook. However, it shuts down this virtual machine when we close the tab or move away from the tab for a long period of time. When we come back to visit this page again, Google will give us another virtual machine. In that case, we need to run the **first code block of this page**. Otherwise, the new virtual machine will not know what `county`, `city`, `populations`, `gas_rating`, `current_average`, or `yesterday_average` are and many of the code blocks below will not work properly.

# %% [markdown]
# ## Practice

# %%
#Run this block first when completing the code blocks in this practice
county = 'San Diego'
city = "San Marcos"
populations = 70301
gas_rating = 87
current_average = 5.013
yesterday_average = 5.025

# %% [markdown]
# Complete the following code blocks based on comments provided.

# %%
#Retrieve values stored in gas_rating

# %%
#Retrieve values stored in current_average and yesterday_average

# %%
#Retrieve values of any three variables in the assignments block

# %%
#Create an assignment statement to store a value of your choice into a descriptive variable name.
#Write the variable name you used in the above code block to show what has been stored in the variable.

# %% [markdown]
# # The print function

# %% [markdown]
# In Python, a **function** is defined to carry out a specific task. There are many functions available and we will help you learn how to use them as they become handy for your tasks. When we use a function in our program, we say we make a **function call** or we call the function.
#
# To call a function, we start with the name of the function, followed by a pair of parentheses. Within the parentheses, we provide information needed for the function to carry out its tasks. We call the items inside the parentheses **parameters** or **arguments**.
#
# We will be using many functions to perform data related tasks.

# %% [markdown]
# The `print` function is designed to help display information. When calling the `print` function, the pair of parenthese after the function name is used to enclose the items to be displayed. By default, each `print` function displays one line. The following code block shows three example calls to the `print` function.
#
# *   A `print` function call with nothing inside the parentheses will display an empty line.
# *   A `print` function call with a specific value inside the parentheses will display the value.
# *   A `print` function call with a variable inside the parentheses will display the value assigned to the variable. If you didn't run the code block above, Python will not know what to display for `county`.

# %%
print()
print('California')
print()
print(county)
# Out:
# California
#
# San Diego

# %% [markdown]
# Each `print` function call can include multiple items inside the parentheses by separating them using commas. Text within quotes will be displayed as-is but Python will display the values of variables provided.

# %%
print("We're interested in the", county, 'county.')
print('The current average gas price for', gas_rating, 'octane is', current_average)
# Out:
# We're interested in the San Diego county.
# The current average gas price for 87 octane is 5.013

# %% [markdown]
# ***Printting via f-string***
#
# Python offers a powerful feature called **f-strings** (formatted string literals) to provide a concise and intuitive way to embed variables directly into strings. To create an **f-string**, we simply prefix the string with the letter f. Within the string, we can then use a pair of **curly bracket** to include a variable.
#
# For example, in the following code block, we use easily use f-string to embed two variables into one sentence.

# %%
state = 'California'
data = 331.4
print(f'According to the 2020 Census, the population for {state} reached {data} million.')
# Out:
# According to the 2020 Census, the population for California reached 331.4 million.

# %% [markdown]
# ## Practice

# %% [markdown]
# Complete the following code block according to the comments provided.

# %%
# Think of one nominal data and assign it to a descriptive variable.
# Use the variable name to show the value of the variable.

# %%
# Think of one categorical data and assign it to a descriptive variable.
# Use the variable name to show the value of the variable.

# %%
# Think of one continuous data and assign it to a descriptive variable.
# Use the variable name to show the value of the variable.

# %%
# Use the print function to display the values of the above variables in a text context.
